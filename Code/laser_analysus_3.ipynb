# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %%
folder_path = '../laser_shots/circles'

# %%
img = cv.imread(f'{folder_path}/16_px.png', cv.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')
